# %% [markdown]
# # Lyrics and Chords from Ultimate-Guitar

# %% [markdown]
# ## Dataset loading

# %% [markdown]
# The dataset that I will be using is one found in Kaggle called [Lyrics and Chords from Ultimate-Guitar](https://www.kaggle.com/datasets/taylorflandro/lyrics-and-chords-from-ultimateguitar?resource=download).
#
# In this dataset, each song is separated in sections. The goal is to have only one string of chords per song.

# %%
import os
import pandas as pd

# %%
data_path = "data"
raw_data_path = os.path.join(data_path, "lyrics-and-chords-from-ultimate-guitar")

# %%
raw_data = []
for f in os.listdir(raw_data_path):
    f_path = os.path.join(raw_data_path, f)
    print(f"Loading {f_path}")
    df = pd.read_csv(f_path, index_col=0)
    raw_data.append(df)
raw_data = pd.concat(raw_data, ignore_index=True)
# Out:
# Loading data/lyrics-and-chords-from-ultimate-guitar/hiphop_lyrics_df.csv
# Loading data/lyrics-and-chords-from-ultimate-guitar/rnb_lyrics_df.csv
# Loading data/lyrics-and-chords-from-ultimate-guitar/rock_lyrics_df.csv
# Loading data/lyrics-and-chords-from-ultimate-guitar/country_lyrics_df.csv
# Loading data/lyrics-and-chords-from-ultimate-guitar/pop_lyrics_df.csv

# %%
raw_data.head()
# Out:
#    Song Artist       Song Title         Part                     Chords  \
# 0  Post Malone  FEELING WHITNEY        intro               C Am Fmaj7 C
# 1  Post Malone  FEELING WHITNEY      verse 1   C Am Fmaj7 C C Am F C C7
# 2  Post Malone  FEELING WHITNEY       chorus  Fmaj7 C Fmaj7 C G G7 N.C.
# 3  Post Malone  FEELING WHITNEY  post-chorus               C Am Fmaj7 C
# 4  Post Malone  FEELING WHITNEY      verse 2       C Am F C C Am F C C7
#
#                                               Lyrics   Genre
# 0  Oo oo oo oo oo oo oo Oo oo oo oo oo oo oo Oo o...  hiphop
# 1  And Ive been looking for someone to put up wit...  hiphop
# 2  To each their own and found peace in knowing A...  hiphop
# 3  Oo oo oo oo oo oo oo Oo oo oo oo oo oo oo Oo o...  hiphop
# 4  And Ive been looking for someone that I can bu...  hiphop

# %%
raw_data["Chords"][0]
# Out:
# 'C Am Fmaj7 C'

# %%
total_rows = len(raw_data)
raw_data = raw_data.drop_duplicates()
deduplicated_rows = len(raw_data)

print(f"Found {total_rows - deduplicated_rows} duplicted rows")
# Out:
# Found 310 duplicted rows

# %% [markdown]
# ## Data discovery

# %%
raw_data["Part"].value_counts(normalize=True).head(20)
# Out:
# chorus          0.238766
# intro           0.089537
# verse           0.089202
# verse 2         0.088196
# verse 1         0.086854
# bridge          0.070423
# pre-chorus      0.057009
# outro           0.056673
# instrumental    0.026492
# verse 3         0.020791
# interlude       0.016097
# hook            0.013414
# chorus 2        0.009725
# chorus 1        0.009054
# refrain         0.008384
# post-chorus     0.006036
# solo            0.005701
# chorus 3        0.004359
# pre-chorus 2    0.004359
# verse 4         0.004024
# Name: Part, dtype: float64

# %% [markdown]
# We can see that some rows have no chords. This could be due to bad parsing of the data when creting the original dataset. In some cases the chords are in the 'Lyrics' column.
#
# These errors happen usually in parts where there is no lyrics such as intro, riffs, solos or instrumental parts.

# %%
is_null_chords = raw_data["Chords"].isnull()
null_chords = raw_data[is_null_chords]
print(f"Found {len(null_chords)} rows with no chords")
# Out:
# Found 44 rows with no chords

# %%
null_chords["Part"].value_counts()
# Out:
# intro                                                                         11
# solo                                                                           3
# verse                                                                          2
# interlude                                                                      2
# pre-hook                                                                       2
# outro                                                                          2
# instrumental                                                                   2
# tuning                                                                         1
# intro: ariana grande                                                           1
# intro c#m e a e c#m e a                                                        1
# note                                                                           1
# general riff                                                                   1
# and the chords continue on for the rest of the song                            1
# break                                                                          1
# bridge                                                                         1
# trumpet intro (not relative to capo)                                           1
# guitar solo                                                                    1
# hook                                                                           1
# more instrumentals.....and more soloing ...and make it to meeeeeeeeeeee...     1
# chorus ii x2                                                                   1
# lead                                                                           1
# exiting piano solo                                                             1
# riff                                                                           1
# chorus                                                                         1
# verse riff                                                                     1
# 2x                                                                             1
# chorus x1                                                                      1
# Name: Part, dtype: int64

# %%
null_chords["Song Title"].value_counts()
# Out:
# BATTLE SCARS                      6
# NEVER BE ALONE                    3
# 27                                3
# HOW TO LOVE                       2
# IRIS                              2
# ON MELANCHOLY HILL                1
# LITTLE TALKS                      1
# MAKE IT TO ME                     1
# BE MY MISTAKE                     1
# TREES                             1
# FATHER AND SON                    1
# LOVE ME AGAIN                     1
# DANGEROUS WOMAN                   1
# WHERE IS MY MIND                  1
# R U MINE                          1
# XANNY                             1
# TRAUERFEIER LIED                  1
# MY FAVORITE PART                  1
# REHAB                             1
# GRAND PIANO                       1
# DO I WANNA KNOW                   1
# WHATS UP                          1
# RADIOACTIVE                       1
# I DONT EVEN KNOW YOUR NAME        1
# REDBONE                           1
# SET FIRE TO THE RAIN              1
# REDEMPTION SONG                   1
# SAME LOVE                         1
# SCREEN                            1
# SEND MY LOVE TO YOUR NEW LOVER    1
# NIGHT CHANGES                     1
# OVER AGAIN                        1
# JUMPSUIT                          1
# Name: Song Title, dtype: int64

# %%
raw_data[raw_data["Song Title"]=="BATTLE SCARS"]
# Out:
#                      Song Artist    Song Title  \
# 245  Lupe Fiasco & Guy Sebastian  BATTLE SCARS
# 246  Lupe Fiasco & Guy Sebastian  BATTLE SCARS
# 247  Lupe Fiasco & Guy Sebastian  BATTLE SCARS
# 248  Lupe Fiasco & Guy Sebastian  BATTLE SCARS
# 249  Lupe Fiasco & Guy Sebastian  BATTLE SCARS
# 250  Lupe Fiasco & Guy Sebastian  BATTLE SCARS
# 251  Lupe Fiasco & Guy Sebastian  BATTLE SCARS
# 252  Lupe Fiasco & Guy Sebastian  BATTLE SCARS
# 467  Lupe Fiasco & Guy Sebastian  BATTLE SCARS
# 468  Lupe Fiasco & Guy Sebastian  BATTLE SCARS
# 469  Lupe Fiasco & Guy Sebastian  BATTLE SCARS
# 470  Lupe Fiasco & Guy Sebastian  BATTLE SCARS
# 471  Lupe Fiasco & Guy Sebastian  BATTLE SCARS
# 472  Lupe Fiasco & Guy Sebastian  BATTLE SCARS
# 473  Lupe Fiasco & Guy Sebastian  BATTLE SCARS
# 475  Lupe Fiasco & Guy Sebastian  BATTLE SCARS
# 476  Lupe Fiasco & Guy Sebastian  BATTLE SCARS
#
#                                                   Part  \
# 245                                              intro
# 246                                               hook
# 247  and the chords continue on for the rest of the...
# 248                                              verse
# 249                                           pre-hook
# 250                                               hook
# 251                                              verse
# 252                                           pre-hook
# 467                                              intro
# 468                                               hook
# 469                                              verse
# 470                                           pre-hook
# 471                                               hook
# 472                                              verse
# 473                                           pre-hook
# 475                                             bridge
# 476                                               hook
#
#                             Chords  \
# 245                       Em C G D
# 246                       Em C G D
# 247                            NaN
# 248                            NaN
# 249                            NaN
# 250                            NaN
# 251                            NaN
# 252                            NaN
# 467                       Em C G D
# 468                       Em C G D
# 469     Em C G D Em C G D Em C G D
# 470              Em C G D Em C G D
# 471              Em C G D Em C G D
# 472              Em C G D Em C G D
# 473              Em C G D Em C G D
# 475    Am Em G D Am Em D Am Em G D
# 476  Em C G D Em C G D Em C G D Em
#
#                                                 Lyrics   Genre
# 245  The wound heals but it never does Thats cause ...  hiphop
# 246  These battle scars dont look like theyre fadin...  hiphop
# 247                                                NaN  hiphop
# 248  I wish I never looked I wish I never touched I...  hiphop
# 249  These battle scars dont look like theyre fadin...  hiphop
# 250  I wish I could feel I wish I can love I wish t...  hiphop
# 251  These battle scars dont look like theyre fadin...  hiphop
# 252  These battle scars dont look like theyre fadin...  hiphop
# 467  Hope the wound heals but it never does Thats c...  hiphop
# 468  These battle scars dont look like theyre fadin...  hiphop
# 469  Never let a wound ruin me But I feel like ruin...  hiphop
# 470  I wish I never looked I wish I never touched I...  hiphop
# 471  These battle scars dont look like theyre fadin...  hiphop
# 472  You shouldnt have but you said it It shouldnt ...  hiphop
# 473  I wish I couldnt feel I wish I couldnt love I ...  hiphop
# 475  Cause you set me on fire Ive never felt so ali...  hiphop
# 476  These battle scars dont look like theyre fadin...  hiphop

# %% [markdown]
# ## Special characters

# %% [markdown]
# First lets see the different chords present in the original dataset. We see that there are other information a part from normal chrods like annotations or symbols like x2 that inticate repetition.

# %%
from collections import Counter
chords = []
for s in raw_data[~is_null_chords]["Chords"]:
    chords.extend(s.split())
chords = Counter(chords)

# %%
len(chords)
# Out:
# 445

# %%
chords.most_common()
# Out:
# [('G', 6396),
#  ('C', 5617),
#  ('D', 3492),
#  ('Am', 3435),
#  ('Em', 3043),
#  ('F', 2851),
#  ('A', 1579),
#  ('Dm', 1151),
#  ('E', 1021),
#  ('Bm', 1016),
#  ('F#m', 525),
#  ('Bb', 495),
#  ('B', 482),
#  ('Gm', 388),
#  ('Eb', 370),
#  ('C#m', 333),
#  ('Cm', 285),
#  ('Em7', 269),
#  ('F#', 254),
#  ('Cadd9', 254),
#  ('Am7', 229),
#  ('Cmaj7', 203),
#  ('Fmaj7', 198),
#  ('Ab', 197),
#  ('G#m', 189),
#  ('N.C.', 185),
#  ('Dsus4', 167),
#  ('Fm', 150),
#  ('B7', 116),
#  ('D7', 116),
#  ('D#m', 110),
#  ('A7', 107),
#  ('-', 88),
#  ('C#', 84),
#  ('E7', 74),
#  ('Dm7', 73),
#  ('Dmaj7', 69),
#  ('Gmaj7', 61),
#  ('G#', 58),
#  ('D#', 54),
#  ('G7', 52),
#  ('Asus2', 51),
#  ('C#m7', 51),
#  ('A7sus4', 48),
#  ('x2', 47),
#  ('A5', 46),
#  ('D6', 46),
#  ('Dsus2', 45),
#  ('Amaj7', 43),
#  ('G6', 42),
#  ('F7', 38),
#  ('C#5', 37),
#  ('Gsus4', 35),
#  ('Bm7', 35),
#  ('Bbm', 33),
#  ('Db', 31),
#  ('C6', 31),
#  ('Gb', 29),
#  ('C7', 28),
#  ('the', 28),
#  ('Amaj9', 25),
#  ('Dmaj9', 25),
#  ('A#', 25),
#  ('E6', 25),
#  ('Cm7', 24),
#  ('F#13', 24),
#  ('Am9', 24),
#  ('F#m11', 24),
#  ('D7sus4', 23),
#  ('Dadd11', 20),
#  ('Emaj7', 20),
#  ('I', 20),
#  ('Gsus', 20),
#  ('(C', 20),
#  ('Abm7', 19),
#  ('Bbm7', 18),
#  ('Bbmadd11(#5)', 18),
#  ('Bbmaj7', 18),
#  ('C#9', 17),
#  ('G#m7', 17),
#  ('Asus4', 17),
#  ('(C)', 16),
#  ('D5', 15),
#  ('G#m6', 15),
#  ('=', 14),
#  ('of', 13),
#  ('F6', 13),
#  ('E5', 13),
#  ('Emadd9', 13),
#  ('Gsus2', 13),
#  ('%', 12),
#  ('G5', 12),
#  ('Bb5', 12),
#  ('Csus2', 11),
#  ('Fadd9', 11),
#  ('(hold)', 11),
#  ('Fsus4', 11),
#  ('on', 10),
#  ('F#m7', 10),
#  ('Fmaj7sus2', 10),
#  ('(x2)', 10),
#  ('Db7', 10),
#  ('Db7sus4', 10),
#  ('D#m7', 10),
#  ('(G)', 10),
#  ('x4', 9),
#  ('C#7', 9),
#  ('Dsus', 9),
#  ('C5', 9),
#  ('a', 8),
#  ('(', 8),
#  (')', 8),
#  ('S', 8),
#  ('(slide', 7),
#  ('one', 7),
#  ('my', 7),
#  ('Aadd9', 7),
#  ('B7sus2', 7),
#  ('Fsus2', 7),
#  ('CM', 7),
#  ('Faug', 7),
#  ('in', 6),
#  ('Esus4', 6),
#  ('Gadd9', 6),
#  (':', 6),
#  ('x3', 6),
#  ('only', 5),
#  ('with', 5),
#  ('or', 5),
#  ('Ab7', 5),
#  ('Gm7', 5),
#  ('(G', 5),
#  ('(strum', 5),
#  ('to', 5),
#  ('Cmmaj7', 5),
#  ('Bsus2', 5),
#  ('(abrupt', 4),
#  ('stop)', 4),
#  ('know', 4),
#  ('out', 4),
#  ('just', 4),
#  ('N.C', 4),
#  ('Cm9', 4),
#  ('Dadd9', 4),
#  ('G#dim', 4),
#  ('F13', 4),
#  ('Cm6', 4),
#  ('Em9', 4),
#  ('Bm9', 4),
#  ('Q', 4),
#  ('E.S', 4),
#  ('three', 4),
#  ('times)', 4),
#  ('Am11', 4),
#  ('Gmaj9', 4),
#  ('B5', 4),
#  ('Ebm7', 4),
#  ('End', 3),
#  ('is', 3),
#  ('(x4)', 3),
#  ('no', 3),
#  ('throughout', 3),
#  ('--2--', 3),
#  ('Ebm', 3),
#  ('Fdim', 3),
#  ('go', 3),
#  ('(slide)', 3),
#  ('whole', 3),
#  ('Esus', 3),
#  ('A#m', 3),
#  ('Abm', 3),
#  ('(Em', 3),
#  ('Em)', 3),
#  ('back', 3),
#  ('D4', 3),
#  ('A2', 3),
#  ('(x3)', 3),
#  ('Cdim', 3),
#  ('E9', 3),
#  ('Gdim7', 3),
#  ('Am7b5', 3),
#  ('Cmaj', 2),
#  ('head?', 2),
#  ('mind?', 2),
#  ('going', 2),
#  ('The', 2),
#  ('quick', 2),
#  ('chord)', 2),
#  ('couple', 2),
#  ('talking', 2),
#  ('baby', 2),
#  ('you', 2),
#  ('can', 2),
#  ('it', 2),
#  ('as', 2),
#  ('first', 2),
#  ('--0--', 2),
#  ('verse)', 2),
#  ('AbM7', 2),
#  ('(G7)', 2),
#  ('Ab7sus4', 2),
#  ('Bb7', 2),
#  ('before', 2),
#  ('chords', 2),
#  ("it's", 2),
#  ('2nd', 2),
#  ('x', 2),
#  ('bad', 2),
#  ("'bout", 2),
#  ('that', 2),
#  ('money', 2),
#  ('slide', 2),
#  ('(G#', 2),
#  ('instead', 2),
#  ('C7sus4', 2),
#  ('2', 2),
#  ('so', 2),
#  ('play', 2),
#  ('Csus4', 2),
#  ('Eb-D-D-C', 2),
#  ('(D)', 2),
#  ('G)', 2),
#  ('pattern', 2),
#  ('this', 2),
#  ('(A)', 2),
#  ('Bbdim7', 2),
#  ('(REPEAT', 2),
#  ('like', 2),
#  ('and', 2),
#  ('A9', 2),
#  ('Bbdim', 2),
#  ('Ddim', 2),
#  ('Abmaj7', 2),
#  ('(hits)', 2),
#  ('Ebaug', 2),
#  ('C#dim', 2),
#  ('vision', 2),
#  ('ecstasy', 2),
#  ('(Em)', 2),
#  ('Bsus4', 2),
#  ('D#m7b5', 2),
#  ('string)', 1),
#  ('x16', 1),
#  ('(This', 1),
#  ('an', 1),
#  ('estimation', 1),
#  ("what's", 1),
#  ('synth', 1),
#  ('part.', 1),
#  ('passing', 1),
#  ('(x6)', 1),
#  ('days', 1),
#  ('seen', 1),
#  ('weeks', 1),
#  ('see', 1),
#  ('(G6)G', 1),
#  ('F(F6)C', 1),
#  ('lunch', 1),
#  ('again', 1),
#  ('Ebsus2', 1),
#  ('(this', 1),
#  ('very', 1),
#  ('move', 1),
#  ('skip', 1),
#  ('hammer', 1),
#  ('on)', 1),
#  ('Ebsus4', 1),
#  ('Ab6', 1),
#  ('[2x]', 1),
#  ('(same', 1),
#  ('intro)', 1),
#  ('(repeated', 1),
#  ('capo', 1),
#  ('fret)', 1),
#  ('5th', 1),
#  ('3rd', 1),
#  ('painting', 1),
#  ('picture', 1),
#  ("that's", 1),
#  ('brain?', 1),
#  ('--4--', 1),
#  ('(Gm', 1),
#  ('D#)', 1),
#  ('verses)', 1),
#  ('Fm7', 1),
#  ('Gmaj', 1),
#  ('(Optional', 1),
#  ('any', 1),
#  ('combination', 1),
#  ('these', 1),
#  ('3', 1),
#  ('Repeat:', 1),
#  ('---', 1),
#  ('(Michael', 1),
#  ('plays', 1),
#  ('"C"', 1),
#  ('shape', 1),
#  ('barre', 1),
#  ('fret', 1),
#  ('3)', 1),
#  ('time', 1),
#  ('(Gm)', 1),
#  ('ends', 1),
#  ('verse', 1),
#  ('mi-llion', 1),
#  ('years', 1),
#  ('4', 1),
#  ('(slide)Em', 1),
#  ('IN', 1),
#  ('SECOND', 1),
#  ('2e', 1),
#  ('inversion)', 1),
#  ('But', 1),
#  ('(Palm', 1),
#  ('Mute)', 1),
#  ('F#5', 1),
#  ('(only', 1),
#  ('sec.)', 1),
#  ('(Keep', 1),
#  ('playing', 1),
#  ('through', 1),
#  ('speech', 1),
#  ('Charlie', 1),
#  ('Chaplin)', 1),
#  ('chords:', 1),
#  ("Nobody's", 1),
#  ('pefect', 1),
#  ('244322', 1),
#  ('454444', 1),
#  ('676666', 1),
#  ('Cmaj9', 1),
#  ('moment', 1),
#  ('solar', 1),
#  ('flare', 1),
#  ("we're", 1),
#  ('consumed', 1),
#  ("woman's", 1),
#  ('voice', 1),
#  ('fox', 1),
#  ('was', 1),
#  ('(Am', 1),
#  ('Sometimes', 1),
#  ("there's", 1),
#  ('keep', 1),
#  ('same', 1),
#  ('picking', 1),
#  ('but', 1),
#  ('use', 1),
#  ('x-3-2-4-x-x', 1),
#  ('x-3-2-2-x-x', 1),
#  ('x-5-5-5-x-x', 1),
#  ('x-5-4-4-x-x', 1),
#  ('5-5-5-5-5-7', 1),
#  ('3-x-4-4-3-5', 1),
#  ('From', 1),
#  ('point', 1),
#  ("won't", 1),
#  ('write', 1),
#  ('down', 1),
#  ('every', 1),
#  ('changes', 1),
#  ('simplify', 1),
#  ('tab.', 1),
#  ('Only', 1),
#  ('(Picking', 1),
#  ('starts)', 1),
#  ('G6sus2', 1),
#  ('(actually', 1),
#  ('Bm7#5)', 1),
#  ('G------------------------------------------------', 1),
#  ('Note:', 1),
#  ('Breaks', 1),
#  ('(Riff)', 1),
#  ('(Hold', 1),
#  ('G----------------', 1),
#  ('Verse', 1),
#  ('Riff', 1),
#  ('(Under', 1),
#  ('x8', 1),
#  ('4x)', 1),
#  ('8x)', 1),
#  ('(You', 1),
#  ('kind', 1),
#  ('around', 1),
#  ('forth', 1),
#  ('quickly', 1),
#  ('from', 1),
#  ('even', 1),
#  ('Dsus4)', 1),
#  ('(quickly:', 1),
#  ('(E', 1),
#  ('lot', 1),
#  ('background', 1),
#  ('noise!)', 1),
#  ('Esus2', 1),
#  ('(now', 1),
#  ('alternating', 1),
#  ('b', 1),
#  ('&', 1),
#  ('1st', 1),
#  ('F#7', 1),
#  ('D#dim', 1),
#  ('D#7', 1),
#  ('x-x-5-4-3-x', 1),
#  ('x-x-4-2-3-x', 1),
#  ('x-x-3-1-3-x', 1),
#  ('x-x-2-0-3-x', 1),
#  (':x02220', 1),
#  (':x24432', 1),
#  (':x04432', 1),
#  (':320033', 1),
#  (':244222', 1),
#  ('X2', 1),
#  ('(fade)', 1),
#  ('Am6', 1),
#  ('F#dim', 1),
#  ('(F)', 1),
#  ('E7#5', 1),
#  ('С', 1),
#  ('4x', 1),
#  ('(once)', 1),
#  ('(Bm)', 1),
#  ('part', 1),
#  ('major', 1),
#  ('triad', 1),
#  ('fades', 1),
#  ('intro', 1),
#  ('(stop)', 1),
#  ('2x', 1),
#  ('(begin', 1),
#  ('light', 1),
#  ('strums)', 1),
#  ('-once', 1),
#  ('love', 1),
#  ('could', 1),
#  ('deny', 1),
#  ("gettin'...tired?", 1),
#  ('once)', 1),
#  ('(4x)', 1),
#  ('....', 1),
#  ('girl', 1),
#  ('dress', 1),
#  ('cried', 1),
#  ('way', 1),
#  ('home', 1)]

# %%
raw_data[~is_null_chords & raw_data["Chords"].str.contains("-")].head()
# Out:
#            Song Artist           Song Title     Part  \
# 62   twenty one pilots     TEAR IN MY HEART    intro
